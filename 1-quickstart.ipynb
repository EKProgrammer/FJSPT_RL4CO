# %% [markdown]
# # RL4CO Quickstart Notebook
#
# <a href="https://colab.research.google.com/github/ai4co/rl4co/blob/main/examples/1-quickstart.ipynb"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"></a>
#
# [**Documentation**](https://rl4co.readthedocs.io/) |  [**Getting Started**](https://github.com/ai4co/rl4co/tree/main#getting-started) | [**Usage**](https://github.com/ai4co/rl4co/tree/main#usage) | [**Contributing**](#contributing) | [**Paper**](https://arxiv.org/abs/2306.17100) | [**Citation**](#cite-us)

# %% [markdown]
# In this notebook we will train the AttentionModel (AM) on the TSP environment for 20 nodes. On a GPU, this should less than 2 minutes!  🚀

# %% [markdown]
# ![Alt text](https://user-images.githubusercontent.com/48984123/245925317-0db4efdd-1c93-4991-8f09-f3c6c1f35d60.png)

# %% [markdown]
# ### Installation

# %%
## Uncomment the following line to install the package from PyPI
## You may need to restart the runtime in Colab after this
## Remember to choose a GPU runtime for faster training!

# !pip install rl4co
# Out:
# Collecting rl4co
#   Obtaining dependency information for rl4co from https://files.pythonhosted.org/packages/db/6e/48fbfda61a4f9a898530a58ae5a12be6a8b5ad542fc54beb3028b76a14a5/rl4co-0.6.0-py3-none-any.whl.metadata
#   Downloading rl4co-0.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting einops (from rl4co)
#   Obtaining dependency information for einops from https://files.pythonhosted.org/packages/87/62/9773de14fe6c45c23649e98b83231fffd7b9892b6cf863251dc2afa73643/einops-0.8.1-py3-none-any.whl.metadata
#   Downloading einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting hydra-colorlog (from rl4co)
#   Obtaining dependency information for hydra-colorlog from https://files.pythonhosted.org/packages/40/50/a08b0453c18088da369991d015ef3902a9ab532b515a41f1bfbe1394854d/hydra_colorlog-1.2.0-py3-none-any.whl.metadata
#   Downloading hydra_colorlog-1.2.0-py3-none-any.whl.metadata (949 bytes)
# Collecting hydra-core (from rl4co)
#   Obtaining dependency information for hydra-core from https://files.pythonhosted.org/packages/c6/50/e0edd38dcd63fb26a8547f13d28f7a008bc4a3fd4eb4ff030673f22ad41a/hydra_core-1.3.2-py3-none-any.whl.metadata
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightning>=2.1.0 (from rl4co)
#   Obtaining dependency information for lightning>=2.1.0 from https://files.pythonhosted.org/packages/d6/e9/36b340c7ec01dad6f034481e98fc9fc0133307beb05c714c0542af98bbde/lightning-2.6.0-py3-none-any.whl.metadata
#   Downloading lightning-2.6.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 497.0 kB/s eta 0:00:00 0:00:01
# Collecting matplotlib (from rl4co)
#   Obtaining dependency information for matplotlib from https://files.pythonhosted.org/packages/7d/18/95ae2e242d4a5c98bd6e90e36e128d71cf1c7e39b0874feaed3ef782e789/matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached matplotlib-3.10.7-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting omegaconf (from rl4co)
#   Obtaining dependency information for omegaconf from https://files.pythonhosted.org/packages/e3/94/1843518e420fa3ed6919835845df698c7e27e183cb997394e4a670973a65/omegaconf-2.3.0-py3-none-any.whl.metadata
#   Downloading omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pyrootutils (from rl4co)
#   Obtaining dependency information for pyrootutils from https://files.pythonhosted.org/packages/1c/6f/ed601aec632d908b86adbad0e1cc712f7073faf697134fb0465a3fbcc512/pyrootutils-1.0.4-py3-none-any.whl.metadata
#   Downloading pyrootutils-1.0.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting rich (from rl4co)
#   Obtaining dependency information for rich from https://files.pythonhosted.org/packages/25/7a/b0178788f8dc6cafce37a212c99565fa1fe7872c70c6c9c1e1a372d9d88f/rich-14.2.0-py3-none-any.whl.metadata
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Collecting robust-downloader (from rl4co)
#   Obtaining dependency information for robust-downloader from https://files.pythonhosted.org/packages/56/a1/779e9d0ebbdc704411ce30915a1105eb01aeaa9e402d7e446613ff8fb121/robust_downloader-0.0.2-py3-none-any.whl.metadata
#   Downloading robust_downloader-0.0.2-py3-none-any.whl.metadata (4.1 kB)
# Collecting scipy (from rl4co)
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/79/2e/415119c9ab3e62249e18c2b082c07aff907a273741b3f8160414b0e9193c/scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached scipy-1.16.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting tensordict>=0.6.0 (from rl4co)
#   Obtaining dependency information for tensordict>=0.6.0 from https://files.pythonhosted.org/packages/5e/05/6e7d130c5e9af947fad25fb7d40a3aa2fd9ef9d37c9c7ddc94ba11853d23/tensordict-0.10.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata
#   Downloading tensordict-0.10.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (9.3 kB)
# Collecting torchrl>=0.6.0 (from rl4co)
#   Obtaining dependency information for torchrl>=0.6.0 from https://files.pythonhosted.org/packages/5e/d0/1a7c5e2bb32ce68304c2a114d105b30a0ae5d9b782719e476590edb9ac06/torchrl-0.10.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata
#   Downloading torchrl-0.10.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.4/48.4 kB 985.4 kB/s eta 0:00:00 0:00:01
# Collecting wandb (from rl4co)
#   Obtaining dependency information for wandb from https://files.pythonhosted.org/packages/5c/ee/9a8bb9a39cc1f09c3060456cc79565110226dc4099a719af5c63432da21d/wandb-0.23.1-py3-none-manylinux_2_28_x86_64.whl.metadata
#   Downloading wandb-0.23.1-py3-none-manylinux_2_28_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: PyYAML<8.0,>5.4 in ./.venv/lib/python3.12/site-packages (from lightning>=2.1.0->rl4co) (6.0.3)
# Collecting fsspec[http]<2027.0,>=2022.5.0 (from lightning>=2.1.0->rl4co)
#   Obtaining dependency information for fsspec[http]<2027.0,>=2022.5.0 from https://files.pythonhosted.org/packages/51/c7/b64cae5dba3a1b138d7123ec36bb5ccd39d39939f18454407e5468f4763f/fsspec-2025.12.0-py3-none-any.whl.metadata
#   Using cached fsspec-2025.12.0-py3-none-any.whl.metadata (10 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning>=2.1.0->rl4co)
#   Obtaining dependency information for lightning-utilities<2.0,>=0.10.0 from https://files.pythonhosted.org/packages/de/73/3d757cb3fc16f0f9794dd289bcd0c4a031d9cf54d8137d6b984b2d02edf3/lightning_utilities-0.15.2-py3-none-any.whl.metadata
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging<27.0,>=20.0 in ./.venv/lib/python3.12/site-packages (from lightning>=2.1.0->rl4co) (25.0)
# Collecting torch<4.0,>=2.1.0 (from lightning>=2.1.0->rl4co)
#   Obtaining dependency information for torch<4.0,>=2.1.0 from https://files.pythonhosted.org/packages/19/17/e377a460603132b00760511299fceba4102bd95db1a0ee788da21298ccff/torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata
#   Using cached torch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning>=2.1.0->rl4co)
#   Obtaining dependency information for torchmetrics<3.0,>0.7.0 from https://files.pythonhosted.org/packages/02/21/aa0f434434c48490f91b65962b1ce863fdcce63febc166ca9fe9d706c2b6/torchmetrics-1.8.2-py3-none-any.whl.metadata
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Collecting tqdm<6.0,>=4.57.0 (from lightning>=2.1.0->rl4co)
#   Obtaining dependency information for tqdm<6.0,>=4.57.0 from https://files.pythonhosted.org/packages/d0/30/dc54f88dd4a2b5dc8a0279bdd7270e735851848b762aeb1c1184ed1f6b14/tqdm-4.67.1-py3-none-any.whl.metadata
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in ./.venv/lib/python3.12/site-packages (from lightning>=2.1.0->rl4co) (4.15.0)
# Collecting pytorch-lightning (from lightning>=2.1.0->rl4co)
#   Obtaining dependency information for pytorch-lightning from https://files.pythonhosted.org/packages/77/eb/cc6dbfe70d15318dbce82674b1e8057cef2634ca9f9121a16b8a06c630db/pytorch_lightning-2.6.0-py3-none-any.whl.metadata
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Collecting numpy (from tensordict>=0.6.0->rl4co)
#   Obtaining dependency information for numpy from https://files.pythonhosted.org/packages/b6/23/2a1b231b8ff672b4c450dac27164a8b2ca7d9b7144f9c02d2396518352eb/numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Using cached numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting cloudpickle (from tensordict>=0.6.0->rl4co)
#   Obtaining dependency information for cloudpickle from https://files.pythonhosted.org/packages/88/39/799be3f2f0f38cc727ee3b4f1445fe6d5e4133064ec2e4115069418a5bb6/cloudpickle-3.1.2-py3-none-any.whl.metadata
#   Using cached cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting importlib_metadata (from tensordict>=0.6.0->rl4co)
#   Obtaining dependency information for importlib_metadata from https://files.pythonhosted.org/packages/20/b0/36bd937216ec521246249be3bf9855081de4c5e06a0c9b4219dbeda50373/importlib_metadata-8.7.0-py3-none-any.whl.metadata
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting orjson (from tensordict>=0.6.0->rl4co)
#   Obtaining dependency information for orjson from https://files.pythonhosted.org/packages/46/bf/0993b5a056759ba65145effe3a79dd5a939d4a070eaa5da2ee3180fbb13f/orjson-3.11.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Downloading orjson-3.11.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 kB 580.8 kB/s eta 0:00:0000:01
# Collecting pyvers<0.2.0,>=0.1.0 (from tensordict>=0.6.0->rl4co)
#   Obtaining dependency information for pyvers<0.2.0,>=0.1.0 from https://files.pythonhosted.org/packages/7f/39/c5432f541e6ea1d616dfd6ef42ce02792f7eb42dd44f5ed4439dbe17a58b/pyvers-0.1.0-py3-none-any.whl.metadata
#   Downloading pyvers-0.1.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting colorlog (from hydra-colorlog->rl4co)
#   Obtaining dependency information for colorlog from https://files.pythonhosted.org/packages/6d/c1/e419ef3723a074172b68aaa89c9f3de486ed4c2399e2dbd8113a4fdcaf9e/colorlog-6.10.1-py3-none-any.whl.metadata
#   Using cached colorlog-6.10.1-py3-none-any.whl.metadata (11 kB)
# Collecting antlr4-python3-runtime==4.9.* (from hydra-core->rl4co)
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 1.7 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting contourpy>=1.0.1 (from matplotlib->rl4co)
#   Obtaining dependency information for contourpy>=1.0.1 from https://files.pythonhosted.org/packages/cc/8f/ec6289987824b29529d0dfda0d74a07cec60e54b9c92f3c9da4c0ac732de/contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Using cached contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib->rl4co)
#   Obtaining dependency information for cycler>=0.10 from https://files.pythonhosted.org/packages/e7/05/c19819d5e3d95294a6f5947fb9b9629efb316b96de511b418c53d245aae6/cycler-0.12.1-py3-none-any.whl.metadata
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->rl4co)
#   Obtaining dependency information for fonttools>=4.22.0 from https://files.pythonhosted.org/packages/29/a3/1fa90b95b690f0d7541f48850adc40e9019374d896c1b8148d15012b2458/fonttools-4.61.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata
#   Using cached fonttools-4.61.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (113 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->rl4co)
#   Obtaining dependency information for kiwisolver>=1.3.1 from https://files.pythonhosted.org/packages/70/90/6d240beb0f24b74371762873e9b7f499f1e02166a2d9c5801f4dbf8fa12e/kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata
#   Using cached kiwisolver-1.4.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib->rl4co)
#   Obtaining dependency information for pillow>=8 from https://files.pythonhosted.org/packages/4f/87/424511bdcd02c8d7acf9f65caa09f291a519b16bd83c3fb3374b3d4ae951/pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Using cached pillow-12.0.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib->rl4co)
#   Obtaining dependency information for pyparsing>=3 from https://files.pythonhosted.org/packages/10/5e/1aa9a93198c6b64513c9d7752de7422c06402de6600a8767da1524f9570b/pyparsing-3.2.5-py3-none-any.whl.metadata
#   Using cached pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./.venv/lib/python3.12/site-packages (from matplotlib->rl4co) (2.9.0.post0)
# Collecting python-dotenv>=0.20.0 (from pyrootutils->rl4co)
#   Obtaining dependency information for python-dotenv>=0.20.0 from https://files.pythonhosted.org/packages/14/1b/a298b06749107c305e1fe0f814c6c74aea7b2f1e10989cb30f544a1b3253/python_dotenv-1.2.1-py3-none-any.whl.metadata
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting markdown-it-py>=2.2.0 (from rich->rl4co)
#   Obtaining dependency information for markdown-it-py>=2.2.0 from https://files.pythonhosted.org/packages/94/54/e7d793b573f298e1c9013b8c4dade17d481164aa517d1d7148619c2cedbf/markdown_it_py-4.0.0-py3-none-any.whl.metadata
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.12/site-packages (from rich->rl4co) (2.19.2)
# Requirement already satisfied: requests in ./.venv/lib/python3.12/site-packages (from robust-downloader->rl4co) (2.32.5)
# Collecting click>=8.0.1 (from wandb->rl4co)
#   Obtaining dependency information for click>=8.0.1 from https://files.pythonhosted.org/packages/98/78/01c019cdb5d6498122777c1a43056ebb3ebfeef2076d9d026bfe15583b2b/click-8.3.1-py3-none-any.whl.metadata
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb->rl4co)
#   Obtaining dependency information for gitpython!=3.1.29,>=1.0.0 from https://files.pythonhosted.org/packages/01/61/d4b89fec821f72385526e1b9d9a3a0385dda4a72b206d28049e2c7cd39b8/gitpython-3.1.45-py3-none-any.whl.metadata
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in ./.venv/lib/python3.12/site-packages (from wandb->rl4co) (4.5.1)
# Collecting protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 (from wandb->rl4co)
#   Obtaining dependency information for protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 from https://files.pythonhosted.org/packages/56/13/333b8f421738f149d4fe5e49553bc2a2ab75235486259f689b4b91f96cec/protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl.metadata
#   Downloading protobuf-6.33.2-cp39-abi3-manylinux2014_x86_64.whl.metadata (593 bytes)
# Collecting pydantic<3 (from wand
ch-2.9.1-cp312-cp312-manylinux_2_28_x86_64.whl (899.7 MB)
# Using cached nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
# Using cached nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
# Using cached nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
# Using cached nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
# Using cached nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
# Using cached nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
# Using cached nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
# Using cached nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
# Using cached nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
# Using cached nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
# Using cached nvidia_nccl_cu12-2.27.5-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.3 MB)
# Using cached nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
# Using cached nvidia_nvshmem_cu12-3.3.20-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (124.7 MB)
# Using cached nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
# Using cached triton-3.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (170.5 MB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 1.1 MB/s eta 0:00:00:00:01
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached colorlog-6.10.1-py3-none-any.whl (11 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading orjson-3.11.5-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.0/139.0 kB 126.4 kB/s eta 0:00:00a 0:00:01
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 1.7 MB/s eta 0:00:00:00:01
# Downloading aiohttp-3.13.2-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.0 MB/s eta 0:00:00:00:01
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached fsspec-2025.12.0-py3-none-any.whl (201 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 1.3 MB/s eta 0:00:000:00:01
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Using cached networkx-3.6.1-py3-none-any.whl (2.1 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 5.8 MB/s eta 0:00:00ta 0:00:01
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Downloading multidict-6.7.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.1/256.1 kB 5.5 MB/s eta 0:00:00:00:01
# Downloading propcache-0.4.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (221 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.6/221.6 kB 4.5 MB/s eta 0:00:00ta 0:00:01
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading yarl-1.22.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (377 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.3/377.3 kB 7.8 MB/s eta 0:00:00:00:01
# Building wheels for collected packages: antlr4-python3-runtime
#   Building wheel for antlr4-python3-runtime (pyproject.toml) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144591 sha256=41c5ceb3051b06a27f51db0f7514e57e1bf94ef608868d6a65256e74be52f96a
#   Stored in directory: /home/egor/.cache/pip/wheels/1f/be/48/13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
# Successfully built antlr4-python3-runtime
# Installing collected packages: nvidia-cusparselt-cu12, mpmath, antlr4-python3-runtime, zipp, typing-inspection, triton, tqdm, sympy, smmap, sentry-sdk, pyvers, python-dotenv, pyparsing, pydantic-core, protobuf, propcache, pillow, orjson, omegaconf, nvidia-nvtx-cu12, nvidia-nvshmem-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, multidict, mdurl, lightning-utilities, kiwisolver, fsspec, frozenlist, fonttools, filelock, einops, cycler, colorlog, cloudpickle, click, annotated-types, aiohappyeyeballs, yarl, scipy, robust-downloader, pyrootutils, pydantic, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, markdown-it-py, importlib_metadata, hydra-core, gitdb, contourpy, aiosignal, rich, nvidia-cusolver-cu12, matplotlib, hydra-colorlog, gitpython, aiohttp, wandb, torch, torchmetrics, tensordict, torchrl, pytorch-lightning, lightning, rl4co
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiosignal-1.4.0 annotated-types-0.7.0 antlr4-python3-runtime-4.9.3 click-8.3.1 cloudpickle-3.1.2 colorlog-6.10.1 contourpy-1.3.3 cycler-0.12.1 einops-0.8.1 filelock-3.20.0 fonttools-4.61.0 frozenlist-1.8.0 fsspec-2025.12.0 gitdb-4.0.12 gitpython-3.1.45 hydra-colorlog-1.2.0 hydra-core-1.3.2 importlib_metadata-8.7.0 kiwisolver-1.4.9 lightning-2.6.0 lightning-utilities-0.15.2 markdown-it-py-4.0.0 matplotlib-3.10.7 mdurl-0.1.2 mpmath-1.3.0 multidict-6.7.0 networkx-3.6.1 numpy-2.3.5 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.5 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvshmem-cu12-3.3.20 nvidia-nvtx-cu12-12.8.90 omegaconf-2.3.0 orjson-3.11.5 pillow-12.0.0 propcache-0.4.1 protobuf-6.33.2 pydantic-2.12.5 pydantic-core-2.41.5 pyparsing-3.2.5 pyrootutils-1.0.4 python-dotenv-1.2.1 pytorch-lightning-2.6.0 pyvers-0.1.0 rich-14.2.0 rl4co-0.6.0 robust-downloader-0.0.2 scipy-1.16.3 sentry-sdk-2.47.0 smmap-5.0.2 sympy-1.14.0 tensordict-0.10.0 torch-2.9.1 torchmetrics-1.8.2 torchrl-0.10.1 tqdm-4.67.1 triton-3.5.1 typing-inspection-0.4.2 wandb-0.23.1 yarl-1.22.0 zipp-3.23.0
#
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Imports

# %%
# %load_ext autoreload
# %autoreload 2

import torch

from rl4co.envs import TSPEnv
from rl4co.models import AttentionModelPolicy, REINFORCE
from rl4co.utils.trainer import RL4COTrainer

# %% [markdown]
# ### Environment, Policy and Model
#
# Full documentation of:https://rl4.co/docs/content/api/envs/base/
#
# - Base environment class [here](https://rl4.co/docs/content/api/envs/base/)
# - Base policy class [here](https://rl4.co/docs/content/api/networks/base_policies/)
# - Base model class [here](https://rl4.co/docs/content/api/rl/base/)

# %%
# RL4CO env based on TorchRL
env = TSPEnv(generator_params={'num_loc': 50})

# Policy: neural network, in this case with encoder-decoder architecture
policy = AttentionModelPolicy(env_name=env.name, 
                              embed_dim=128,
                              num_encoder_layers=3,
                              num_heads=8,
                            )

# RL Model: REINFORCE and greedy rollout baseline
model = REINFORCE(env, 
                    policy,
                    baseline="rollout",
                    batch_size=512,
                    train_data_size=100_000,
                    val_data_size=10_000,
                    optimizer_kwargs={"lr": 1e-4},
                    )
# Out:
# /home/egor/cousework/10.12.25/rl4co_try/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/parsing.py:210: Attribute 'env' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['env'])`.
# /home/egor/cousework/10.12.25/rl4co_try/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/parsing.py:210: Attribute 'policy' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['policy'])`.

# %% [markdown]
# ### Test greedy rollout with untrained model and plot

# %%
# Greedy rollouts over untrained policy
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
td_init = env.reset(batch_size=[3]).to(device)
policy = policy.to(device)
out = policy(td_init.clone(), phase="test", decode_type="greedy", return_actions=True)
actions_untrained = out['actions'].cpu().detach()
rewards_untrained = out['reward'].cpu().detach()

for i in range(3):
    print(f"Problem {i+1} | Cost: {-rewards_untrained[i]:.3f}")
    env.render(td_init[i], actions_untrained[i])
# Out:
# Problem 1 | Cost: 14.498
# Problem 2 | Cost: 23.551
# Problem 3 | Cost: 12.228

# %% [markdown]
# ### Trainer
#
# The RL4CO trainer is a wrapper around PyTorch Lightning's `Trainer` class which adds some functionality and more efficient defaults

# %%
trainer = RL4COTrainer(
    max_epochs=3,
    accelerator="gpu",
    devices=1,
    logger=None,
)
# Out:
# Using 16bit Automatic Mixed Precision (AMP)
# 💡 Tip: For seamless cloud uploads and versioning, try installing [litmodels](https://pypi.org/project/litmodels/) to enable LitModelCheckpoint, which syncs automatically with the Lightning model registry.
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# /home/egor/cousework/10.12.25/rl4co_try/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/logger_connector/logger_connector.py:76: Starting from v1.9.0, `tensorboardX` has been removed as a dependency of the `lightning.pytorch` package, due to potential conflicts with other packages in the ML ecosystem. For this reason, `logger=True` will use `CSVLogger` as the default logger, unless the `tensorboard` or `tensorboardX` packages are found. Please `pip install lightning[extra]` or one of them to enable TensorBoard support by default

# %% [markdown]
# ### Fit the model

# %%
trainer.fit(model)
# Out:
# val_file not set. Generating dataset instead
# test_file not set. Generating dataset instead
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# /home/egor/cousework/10.12.25/rl4co_try/.venv/lib/python3.12/site-packages/lightning/pytorch/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name     ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ env      │ TSPEnv               │      0 │ train │     0 │
# │ 1 │ policy   │ AttentionModelPolicy │  710 K │ train │     0 │
# │ 2 │ baseline │ WarmupBaseline       │  710 K │ train │     0 │
# └───┴──────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 1.4 M
# Non-trainable params: 0
# Total params: 1.4 M
# Total estimated model params size (MB): 5
# Modules in train mode: 72
# Modules in eval mode: 68
# Total FLOPs: 0
# Output()
# /home/egor/cousework/10.12.25/rl4co_try/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/dat
# a_connector.py:434: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing
# the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/egor/cousework/10.12.25/rl4co_try/.venv/lib/python3.12/site-packages/lightning/pytorch/trainer/connectors/dat
# a_connector.py:434: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider
# increasing the value of the `num_workers` argument` to `num_workers=11` in the `DataLoader` to improve performance.
# /home/egor/cousework/10.12.25/rl4co_try/.venv/lib/python3.12/site-packages/lightning/pytorch/loops/fit_loop.py:534:
# Found 68 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If
# this is intentional, you can ignore this warning.
# `Trainer.fit` stopped: `max_epochs=3` reached.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# ### Testing

# %%
# Greedy rollouts over trained model (same states as previous plot)
policy = model.policy.to(device)
out = policy(td_init.clone(), phase="test", decode_type="greedy", return_actions=True)
actions_trained = out['actions'].cpu().detach()

# Plotting
import matplotlib.pyplot as plt
for i, td in enumerate(td_init):
    fig, axs = plt.subplots(1,2, figsize=(11,5))
    env.render(td, actions_untrained[i], ax=axs[0]) 
    env.render(td, actions_trained[i], ax=axs[1])
    axs[0].set_title(f"Untrained | Cost = {-rewards_untrained[i].item():.3f}")
    axs[1].set_title(r"Trained $\pi_\theta$" + f"| Cost = {-out['reward'][i].item():.3f}")

# %% [markdown]
# We can see that even after just 3 epochs, our trained AM is able to find much better solutions than the random policy! 🎉

# %%
# Optionally, save the checkpoint for later use (e.g. in tutorials/4-search-methods.ipynb)
trainer.save_checkpoint("tsp-quickstart.ckpt")
# Out:
# `weights_only` was not set, defaulting to `False`.
